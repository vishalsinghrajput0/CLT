# %%
import os
os.chdir('V:\ds lecture\DATA')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('V:\ds lecture\DATA\CLT-master\CLT-master\Population.csv')

# %%
df.head()
# Out:
#             Player  Height  Weight  Age      School       BDate
# 0   Vitor Faverani      83     260   25        None  05-05-1988
# 1    Avery Bradley      74     180   22       Texas  26-11-1990
# 2     Keith Bogans      77     215   33    Kentucky  12-05-1980
# 3  Jared Sullinger      81     260   21  Ohio State  04-03-1992
# 4       Jeff Green      81     235   27  Georgetown  28-08-1986

# %%
import scipy.stats as stats

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=df[['Weight']]

# %%
sns.distplot(df.Weight)
plt.show()

# %%
print(df.Weight.mean())
print(df.Weight.std())
# Out:
# 220.67326732673268
# 26.643110470317723

# %%
sample_size=30

# %%
sample_means=[df.Weight.sample(sample_size).mean() for i in range(1000)]

# %%
sns.distplot(sample_means)
plt.show()

# %%
sample_means=pd.Series(sample_means)

# %%
sample_means
# Out:
# 0      221.433333
# 1      226.266667
# 2      229.000000
# 3      219.066667
# 4      218.000000
#           ...
# 995    220.300000
# 996    216.600000
# 997    215.166667
# 998    209.600000
# 999    228.466667
# Length: 1000, dtype: float64

# %%
sample_means.mean()
# Out:
# 220.5340666666666

# %%
sample_means.std()
# Out:
# 4.651972135709557

# %%
df.Weight.std()/np.sqrt(sample_size)
# Out:
# 4.864344202231697

# %%
df1=pd.read_csv('V:\ds lecture\DATA\CLT-master\CLT-master\Random Values.csv')

# %%
df1.head()
# Out:
#    VAL
# 0  362
# 1  361
# 2  360
# 3  359
# 4  358

# %%
df1.hist(bins=40)
# Out:
# array([[<AxesSubplot:title={'center':'VAL'}>]], dtype=object)

# %%
samp_size=30
sample_mean1=[df1.VAL.sample(samp_size).mean() for i in range(1000)]
sample_mean1=pd.Series(sample_mean1)

# %%
sns.distplot(sample_mean1)
plt.show()

# %%
df1.mean()
# Out:
# VAL    130.418165
# dtype: float64

# %%
sample_mean1.mean()
# Out:
# 129.80236666666661

# %%
sample_sizes=[3,10,30,50,100,200]
plt.figure(figsize=[10,7])
for ind, samp_size in enumerate(sample_sizes):
    sample_means2=[df1.sample(samp_size).mean() for i in range(1000)]
    plt.subplot(2,3,ind+1)
    sns.distplot(sample_means2,bins=25)
    plt.title('Sample size: '+str(samp_size))
plt.show()
